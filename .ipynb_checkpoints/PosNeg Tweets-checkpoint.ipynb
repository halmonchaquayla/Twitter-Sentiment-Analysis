# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/judge-1377884607_tweet_product_company.csv', encoding='latin1')

# %%
df1 = df.drop('emotion_in_tweet_is_directed_at', axis=1)

# %%
df1.rename(columns={'is_there_an_emotion_directed_at_a_brand_or_product':'target'}, 
          inplace=True)
df1
# Out:
#                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1     @jessedee Know about @fludapp ? Awesome iPad/i...
# 2     @swonderlin Can not wait for #iPad 2 also. The...
# 3     @sxsw I hope this year's festival isn't as cra...
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa M...
# ...                                                 ...
# 9088                      Ipad everywhere. #SXSW {link}
# 9089  Wave, buzz... RT @mention We interrupt your re...
# 9090  Google's Zeiger, a physician never reported po...
# 9091  Some Verizon iPhone customers complained their...
# 9092  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
#
#                                   target
# 0                       Negative emotion
# 1                       Positive emotion
# 2                       Positive emotion
# 3                       Negative emotion
# 4                       Positive emotion
# ...                                  ...
# 9088                    Positive emotion
# 9089  No emotion toward brand or product
# 9090  No emotion toward brand or product
# 9091  No emotion toward brand or product
# 9092  No emotion toward brand or product
#
# [9093 rows x 2 columns]

# %% [markdown]
# # Clean Data

# %%
import numpy as np
np.random.seed(0)
import nltk
from nltk import FreqDist, word_tokenize
from nltk.corpus import stopwords
from nltk.collocations import *
import string
import unidecode
import re, collections
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams
import seaborn as sns

# nltk.download('punkt')
# nltk.download('stopwords')

# %%
df1 = df1.replace({'No emotion toward brand or product':'neutral'})
df1 = df1.replace({"I can't tell":'neutral'})
df1 = df1.replace({'Positive emotion':'positive'})
df1 = df1.replace({'Negative emotion':'negative'})

# %%
# only keep positive and negative tweets
df1 = df1[~df1.target.str.contains('neutral')]

# %%
df1['tweet_text'] = df1.tweet_text.astype(str)

# %%
df1['clean_tweet'] = df1['tweet_text'].dropna()

# %% [markdown]
# ## Remove Urls

# %%
def remove_urls(corpus):
#     pattern = re.compile(r'https?:\/\/\S*')
    pattern = re.compile(r"(https?:\/\/)?(www\.)[-a-zA-Z0-9@:%._\+~#=]+\.[a-z]{2,4}\b([-a-zA-Z0-9@:%_\+.~#?&\/\/=]*)|(https?:\/\/)?(www\.)?(?!ww)[-a-zA-Z0-9@:%._\+~#=]+\.[a-z]{2,4}\b([-a-zA-Z0-9@:%_\+.~#?&\/\/=]*)") 
    # captures six different groups of websites
    return pattern.sub(r'', corpus)

df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x:remove_urls(x))

# %%
df1['tweet_text'][8]
# Out:
# 'Beautifully smart and simple idea RT @madebymany @thenextweb wrote about our #hollergram iPad app for #sxsw! http://bit.ly/ieaVOB'

# %%
df1['clean_tweet'][8]
# Out:
# 'Beautifully smart and simple idea RT @madebymany @thenextweb wrote about our #hollergram iPad app for #sxsw! '

# %% [markdown]
# ## Remove Unidecode

# %%
df1['clean_tweet'] = df1['clean_tweet'].apply(unidecode.unidecode)

# %%
df1['tweet_text'][106]
# Out:
# '\x89ÛÏ@mention &quot;Google before you tweet&quot; is the new &quot;think before you speak.&quot; - Mark Belinsky, #911tweets panel at #SXSW.\x89Û\x9d'

# %%
df1['clean_tweet'][106]
# Out:
# 'UI@mention &quot;Google before you tweet&quot; is the new &quot;think before you speak.&quot; - Mark Belinsky, #911tweets panel at #SXSW.U'

# %% [markdown]
# ## Remove Links

# %%
df1['clean_tweet'] = df1['clean_tweet'].str.replace(r"({link})", '')

# %%
df1['tweet_text'][9088]
# Out:
# 'Ipad everywhere. #SXSW {link}'

# %%
df1['clean_tweet'][9088]
# Out:
# 'Ipad everywhere. #SXSW '

# %% [markdown]
# ## Remove Hashtags

# %%
def remove_hashtags(corpus):
    pattern = re.compile(r"\s?([@#][\w_-]+)")
    return pattern.sub(r'', corpus)

df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x:remove_hashtags(x))

# %%
df1['tweet_text'][1]
# Out:
# "@jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW"

# %%
df1['clean_tweet'][1]
# Out:
# " Know about ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at"

# %% [markdown]
# ## Remove Numbers

# %%
def remove_numbers(corpus):
    pattern = re.compile(r"\d.?")
    return pattern.sub(r'', corpus)

df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x: remove_numbers(x))

# %%
df1['tweet_text'][0]
# Out:
# '.@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.'

# %%
df1['clean_tweet'][0]
# Out:
# '. I have a  iPhone. After hrs tweeting at, it was dead!  I need to upgrade. Plugin stations at.'

# %% [markdown]
# ## Lowercase Text

# %%
df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df1['clean_tweet'].head()
# Out:
# 0    . i have a iphone. after hrs tweeting at, it w...
# 1    know about ? awesome ipad/iphone app that you'...
# 2    can not wait for also. they should sale them d...
# 3    i hope this year's festival isn't as crashy as...
# 4    great stuff on fri: marissa mayer (google), ti...
# Name: clean_tweet, dtype: object

# %% [markdown]
# ## Stopwords

# %%
stopwords_list = stopwords.words('english')
lemmatizer = WordNetLemmatizer()

# %%
print(stopwords_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
df1['char_count'] = df1['tweet_text'].str.len() #how many characters do we have in description? 
print(df1[['tweet_text','char_count']].head())
print(df1['char_count'].mean())
# Out:
#                                           tweet_text  char_count
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...         127
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...         139
# 2  @swonderlin Can not wait for #iPad 2 also. The...          79
# 3  @sxsw I hope this year's festival isn't as cra...          82
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...         131
# 106.18348365276212

# %%
# extract stopwords
df1['stopwords'] = df1['tweet_text'].apply(lambda x: len([x for x in x.split() if x in stopwords_list]))
df1[['tweet_text','stopwords']].head(10)
# Out:
#                                            tweet_text  stopwords
# 0   .@wesley83 I have a 3G iPhone. After 3 hrs twe...          7
# 1   @jessedee Know about @fludapp ? Awesome iPad/i...          6
# 2   @swonderlin Can not wait for #iPad 2 also. The...          6
# 3   @sxsw I hope this year's festival isn't as cra...          5
# 4   @sxtxstate great stuff on Fri #SXSW: Marissa M...          1
# 7   #SXSW is just starting, #CTIA is around the co...         14
# 8   Beautifully smart and simple idea RT @madebyma...          4
# 9   Counting down the days to #sxsw plus strong Ca...          5
# 10  Excited to meet the @samsungmobileus at #sxsw ...          7
# 11  Find &amp; Start Impromptu Parties at #SXSW Wi...          2

# %%
# remove stopwords
df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stopwords_list))
df1['clean_tweet'].head()
# Out:
# 0    . iphone. hrs tweeting at, dead! need upgrade....
# 1    know ? awesome ipad/iphone app likely apprecia...
# 2                                  wait also. sale at.
# 3       hope year's festival crashy year's iphone app.
# 4    great stuff fri: marissa mayer (google), tim o...
# Name: clean_tweet, dtype: object

# %% [markdown]
# ## Remove Punctuation

# %%
def remove_punct(corpus):
    pattern = re.compile(r"[\|\^\+\[\]\(\),~\'?\.\/{}=!$%&:;_-]") # Match any character in set
    return pattern.sub(r' ', corpus)

df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x:remove_punct(x))

# %%
df1['tweet_text'][1]
# Out:
# "@jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW"

# %%
df1['clean_tweet'][1]
# Out:
# 'know   awesome ipad iphone app likely appreciate design  also  they re giving free ts'

# %%
# remove again in case some words weren't removed
df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stopwords_list))
df1['clean_tweet'].head()
# Out:
# 0    iphone hrs tweeting dead need upgrade plugin s...
# 1    know awesome ipad iphone app likely appreciate...
# 2                                       wait also sale
# 3            hope year festival crashy year iphone app
# 4    great stuff fri marissa mayer google tim reill...
# Name: clean_tweet, dtype: object

# %% [markdown]
# ## Extra cleaning

# %%
# remove one or two letter words
def remove_singles(corpus):
    pattern = re.compile(r"(\b\w?\w\b)") # Match any single letter or 2 letter words in set
    return pattern.sub(r' ', corpus)

df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x:remove_singles(x))

# %%
def remove_quot(corpus):
    pattern = re.compile(r"\s(quot)\s") #remove the word quot from tweets
    return pattern.sub(r' ', corpus)

df1['clean_tweet'] = df1['clean_tweet'].apply(lambda x:remove_quot(x))

# %% [markdown]
# ## Create one string from column

# %%
tweet_str = ' '.join(df1['clean_tweet'].tolist())
tweet_str
# Out:
# 'iphone hrs tweeting dead need upgrade plugin stations know awesome ipad iphone app likely appreciate design also giving free   wait also sale hope year festival crashy year iphone app great stuff fri marissa mayer google tim reilly tech books conferences amp matt mullenweg wordpress starting around corner hop skip jump good time fan beautifully smart simple idea   wrote ipad app counting days plus strong canadian dollar means stock apple gear excited meet show sprint galaxy still running android find amp start impromptu parties wait til android app comes foursquare ups game time still prefer far best looking android app date gotta love google calendar featuring top parties show cases check   via   great ipad app haha awesomely rad ipad app noticed dst coming weekend many iphone users hour late sxsw come sunday morning added flights matching people planes airports also downloaded iphone app nicely done must app   lovely review forbes sxsw ipad app holler gram need buy ipadwhile austin sure need   austin apple store   god app ipad pure unadulterated awesome easier browse events ipad website okay really yay new app kthxbai photo installed iphone app really nice really enjoying changes gowalla android looking forward seeing else amp foursquare sleeves   looking forward pre party wed hoping win resulting shameless promotion   haha awesomely rad ipad app via someone started group google groups pre great idea new looks like going rock update iphone android push tonight right app sweeeeet nice job team smart ipad app may leave vuvuzela home must app ipad going best     first line pop apple store event planner false alarm google circles coming nowuoand probably ever great weather greet still need sweater night apple putting flash store downtown sell ipad   opens instant access waited get one hand held   hoboua drafthouse launches   hobo shotgunua iphone app hooray     apple opening pop store austin wooooo   apple store downtown austin open til midnight   talking google effort allow users open systems   stop amp hunt austin java get spy game chance win ipad   heard apple pop store downtown austin pics already gowalla   line apple store insane attending ipad design headaches boooo   flipboard developing iphone version android says check amp line ipad austin power   come party   google tonight bands food art ice cream nifty interactive maps holla   google party best ever get butt love iphone case get phone new post iphone app makes easy connect social networks people meet nice iphone app behaving today crashes yesterday ridiculous nice   hey apple fans get peek space slated pop apple store tomorrow one thing great get great earth face google company love thanks mention new ipad apps showcased conf provide iphone chargers changed mind going next year xmas   shiny new apps new book pop ipad stores christmas nerds yai   new app store includes uberguide sponsored cont fast fun amp future google presenting search local mobile headline must gadget hmm could seen one coming know dataviz translates satanic iphone sayin quot google launched checkins month ago check ins   check outs future   google tweet new think speak mark belinsky panel   kawasaki   lewis level reasoning apple continued existence evidence existence god quot kawasaki pagemaker saved apple   days via spark award read ipad great thoughts   japan apac regions dealing   earthquake amp tsunami trauma schools marketing experts temporary store def tent powerhouse gym temporary store   congress along happy hipsters   wins opening temporary store downtown austin support launch good trending today fun nerdy nerds christian devs want talk   maybe   together cool app apple taken storm excited part haz ifrom   stacks waiting bought got mine hassle apple handled perfectly need reviews play google places got app take   major south korean director gets make movie entirely iphone beautiful apple store sxsw pic must app   lovely review forbes sxsw ipad app holler gram temporary apple store apple  ...

# %%
# get rid of extra whitespaces
tweet_str = " ".join(tweet_str.split())
tweet_str
# Out:
# 'iphone hrs tweeting dead need upgrade plugin stations know awesome ipad iphone app likely appreciate design also giving free wait also sale hope year festival crashy year iphone app great stuff fri marissa mayer google tim reilly tech books conferences amp matt mullenweg wordpress starting around corner hop skip jump good time fan beautifully smart simple idea wrote ipad app counting days plus strong canadian dollar means stock apple gear excited meet show sprint galaxy still running android find amp start impromptu parties wait til android app comes foursquare ups game time still prefer far best looking android app date gotta love google calendar featuring top parties show cases check via great ipad app haha awesomely rad ipad app noticed dst coming weekend many iphone users hour late sxsw come sunday morning added flights matching people planes airports also downloaded iphone app nicely done must app lovely review forbes sxsw ipad app holler gram need buy ipadwhile austin sure need austin apple store god app ipad pure unadulterated awesome easier browse events ipad website okay really yay new app kthxbai photo installed iphone app really nice really enjoying changes gowalla android looking forward seeing else amp foursquare sleeves looking forward pre party wed hoping win resulting shameless promotion haha awesomely rad ipad app via someone started group google groups pre great idea new looks like going rock update iphone android push tonight right app sweeeeet nice job team smart ipad app may leave vuvuzela home must app ipad going best first line pop apple store event planner false alarm google circles coming nowuoand probably ever great weather greet still need sweater night apple putting flash store downtown sell ipad opens instant access waited get one hand held hoboua drafthouse launches hobo shotgunua iphone app hooray apple opening pop store austin wooooo apple store downtown austin open til midnight talking google effort allow users open systems stop amp hunt austin java get spy game chance win ipad heard apple pop store downtown austin pics already gowalla line apple store insane attending ipad design headaches boooo flipboard developing iphone version android says check amp line ipad austin power come party google tonight bands food art ice cream nifty interactive maps holla google party best ever get butt love iphone case get phone new post iphone app makes easy connect social networks people meet nice iphone app behaving today crashes yesterday ridiculous nice hey apple fans get peek space slated pop apple store tomorrow one thing great get great earth face google company love thanks mention new ipad apps showcased conf provide iphone chargers changed mind going next year xmas shiny new apps new book pop ipad stores christmas nerds yai new app store includes uberguide sponsored cont fast fun amp future google presenting search local mobile headline must gadget hmm could seen one coming know dataviz translates satanic iphone sayin quot google launched checkins month ago check ins check outs future google tweet new think speak mark belinsky panel kawasaki lewis level reasoning apple continued existence evidence existence god quot kawasaki pagemaker saved apple days via spark award read ipad great thoughts japan apac regions dealing earthquake amp tsunami trauma schools marketing experts temporary store def tent powerhouse gym temporary store congress along happy hipsters wins opening temporary store downtown austin support launch good trending today fun nerdy nerds christian devs want talk maybe together cool app apple taken storm excited part haz ifrom stacks waiting bought got mine hassle apple handled perfectly need reviews play google places got app take major south korean director gets make movie entirely iphone beautiful apple store sxsw pic must app lovely review forbes sxsw ipad app holler gram temporary apple store apple sneaky usual beta testing interactive book ipad app moonbot studios louisiana cool a ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Tokenize

# %%
tokens = nltk.word_tokenize(tweet_str)
print(len(tokens))
# Out:
# 31002

# %% [markdown]
# ## Lemmatize text

# %%
lemma_tweet = lambda x: lemmatize_text(x)
lemma = WordNetLemmatizer()
tokens = [lemma.lemmatize(token) for token in tokens]

# %% [markdown]
# ## Word Cloud

# %%
# count of all the tokens
from collections import Counter
count = Counter(tokens)
common_tag_200 = count.most_common(16208)
common_tag_200[:10]
# Out:
# [('ipad', 1151),
#  ('apple', 861),
#  ('google', 803),
#  ('iphone', 618),
#  ('store', 602),
#  ('app', 449),
#  ('new', 402),
#  ('austin', 282),
#  ('amp', 233),
#  ('pop', 230)]

# %%
from wordcloud import WordCloud

wc = WordCloud(background_color="white", width=3200, height=2400)
cloud = wc.generate_from_frequencies(dict(common_tag_200))
plt.figure(figsize=(20, 16))
plt.axis('off')
plt.imshow(cloud)
plt.show()

# %% [markdown]
# **So of course the most frequent words are the brands we're focused on: google and apple. Then we get some products and descriptions such as iPad, iPhone, new, and free.**

# %% [markdown]
# ## Word Clouds By Emotion

# %%
# create seperate dataframes for each emotion and their common words
pos_comments = df1[df1['target'] == 'positive']['clean_tweet']
pos_words = ' '.join(pos_comments).split()
pos_words_df = pd.DataFrame(pos_words, columns=['words'])['words'].value_counts()[1:]

# neut_comments = df1[df1['target'] == 'neutral']['clean_tweet']
# neut_words = ' '.join(neut_comments).split()
# neut_words = pd.DataFrame(neut_words, columns=['words'])['words'].value_counts()[1:]

neg_comments = df1[df1['target'] == 'negative']['clean_tweet']
neg_words = ' '.join(neg_comments).split()
neg_words_df = pd.DataFrame(neg_words, columns=['words'])['words'].value_counts()[1:]

# %%
pos_wc = WordCloud(width=1280, height=880, collocations=False, random_state=42,
                      colormap='Purples', background_color='white', max_words=50)
pos_wc = pos_wc.generate_from_frequencies(pos_words_df)

# neut_wc = WordCloud(width=1280, height=880, collocations=False, random_state=42,
#                       colormap='Blues', background_color='white', max_words=50)
# neut_wc = neut_wc.generate_from_frequencies(neut_words)

neg_wc = WordCloud(width=1280, height=880, collocations=False, random_state=42,
                      colormap='Reds', background_color='white', max_words=50)
neg_wc = neg_wc.generate_from_frequencies(neg_words_df)

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 20))

axes[0].set_title('WordCloud for Positive', size=25, pad=20)
axes[0].imshow(pos_wc)
axes[0].axis('off')

# axes[1].set_title('WordCloud for Neutral', size=25, pad=20)
# axes[1].imshow(neut_wc)
# axes[1].axis('off')

axes[1].set_title('WordCloud for Negative', size=25, pad=20)
axes[1].imshow(neg_wc)
axes[1].axis('off')

fig.subplots_adjust(hspace=1,wspace=0.0)

# %% [markdown]
# **We can see words like amp, awesome, and get in the positive word clouds. Battery, line, headaches in negative word clouds. You can also see there are common words among all the word clouds, meaning that words alone can have a lot of different meaning. We need to get more context from each tweet to understand the reasoning of the sentiment.**

# %% [markdown]
# ## Pos Tag

# %%
# find and count all the tags in dataframe
token_pos = nltk.pos_tag(tokens)
postags_df = pd.DataFrame(token_pos, columns=('word', 'POS'))
pos_sum = postags_df.groupby('POS', as_index=False).count()
pos_sum.sort_values(['word'], ascending=False)
# Out:
#     POS   word
# 10   NN  15661
# 6    JJ   6059
# 22  VBG   1600
# 14   RB   1484
# 24  VBP   1282
# 21  VBD    999
# 20   VB    765
# 5    IN    730
# 12  NNS    637
# 23  VBN    568
# 2    CD    266
# 9    MD    207
# 25  VBZ    187
# 8   JJS    132
# 3    DT     82
# 11  NNP     74
# 7   JJR     72
# 15  RBR     50
# 4    FW     46
# 1    CC     18
# 17   RP     17
# 18   TO     17
# 13  PRP     14
# 19   UH     13
# 0     #      7
# 26  WDT      5
# 16  RBS      4
# 27   WP      3
# 28  WRB      3

# %%
#getting just the nouns, verbs, and adjectives
filtered_pos = [ ]
for one in token_pos:
    if one[1] == 'NN' or one[1] == 'NNS' or one[1] == 'NNP' or one[1] == 'NNPS' or one[1] == 'VBP' or one[1] == 'VBN' or one[1] == 'VBD' or one[1] == 'VB' or one[1] == 'VBZ' or one[1] == 'JJ' or one[1] == 'JJR' or one[1] == 'JJS':
        filtered_pos.append(one)
print (len(filtered_pos))
# Out:
# 26436

# %%
fdist_pos = nltk.FreqDist(filtered_pos)
top_100_words = fdist_pos.most_common(100)
print(top_100_words)
# Out:
# [(('apple', 'NN'), 861), (('google', 'NN'), 599), (('store', 'NN'), 595), (('ipad', 'NN'), 590), (('iphone', 'NN'), 516), (('ipad', 'JJ'), 436), (('new', 'JJ'), 402), (('app', 'NN'), 291), (('pop', 'NN'), 206), (('austin', 'NN'), 199), (('line', 'NN'), 163), (('time', 'NN'), 160), (('party', 'NN'), 154), (('social', 'JJ'), 150), (('day', 'NN'), 147), (('great', 'JJ'), 145), (('launch', 'NN'), 139), (('amp', 'NN'), 134), (('today', 'NN'), 132), (('circle', 'NN'), 131), (('quot', 'NN'), 123), (('free', 'JJ'), 120), (('google', 'JJ'), 119), (('people', 'NNS'), 112), (('sxsw', 'NN'), 112), (('network', 'NN'), 109), (('good', 'JJ'), 105), (('map', 'NN'), 105), (('got', 'VBD'), 96), (('temporary', 'JJ'), 94), (('get', 'VB'), 92), (('open', 'JJ'), 90), (('year', 'NN'), 86), (('cool', 'JJ'), 83), (('awesome', 'JJ'), 82), (('android', 'JJ'), 81), (('downtown', 'NN'), 76), (('called', 'VBN'), 76), (('app', 'JJ'), 74), (('thanks', 'NNS'), 73), (('major', 'JJ'), 73), (('mayer', 'NN'), 72), (('apps', 'NN'), 71), (('design', 'NN'), 70), (('android', 'NN'), 70), (('mobile', 'JJ'), 70), (('best', 'JJS'), 67), (('popup', 'NN'), 67), (('thing', 'NN'), 66), (('phone', 'NN'), 64), (('iphone', 'JJ'), 63), (('check', 'NN'), 62), (('case', 'NN'), 59), (('get', 'VBP'), 59), (('next', 'JJ'), 59), (('austin', 'JJ'), 56), (('google', 'VBP'), 56), (('product', 'NN'), 56), (('come', 'VBP'), 55), (('get', 'NN'), 54), (('panel', 'NN'), 54), (('game', 'NN'), 53), (('look', 'NN'), 53), (('want', 'VBP'), 53), (('news', 'NN'), 53), (('shop', 'NN'), 53), (('need', 'VBP'), 52), (('nice', 'JJ'), 51), (('say', 'VBP'), 51), (('set', 'VBN'), 51), (('big', 'JJ'), 51), (('session', 'NN'), 51), (('love', 'NN'), 50), (('think', 'VBP'), 50), (('conference', 'NN'), 49), (('video', 'NN'), 49), (('team', 'NN'), 48), (('way', 'NN'), 48), (('launch', 'JJ'), 48), (('talk', 'NN'), 46), (('last', 'JJ'), 46), (('world', 'NN'), 46), (('know', 'VBP'), 45), (('use', 'NN'), 45), (('week', 'NN'), 45), (('everyone', 'NN'), 45), (('search', 'NN'), 44), (('technology', 'NN'), 44), (('guy', 'NN'), 44), (('smart', 'JJ'), 43), (('ipad', 'NNS'), 43), (('amp', 'JJ'), 42), (('hour', 'NN'), 42), (('win', 'VBP'), 42), (('user', 'JJ'), 40), (('marketing', 'NN'), 40), (('make', 'VBP'), 40), (('fun', 'NN'), 39), (('location', 'NN'), 39), (('rumor', 'NN'), 38)]

# %%
top_words_df = pd.DataFrame(top_100_words, columns = ('pos','count'))
top_words_df['Word'] = top_words_df['pos'].apply(lambda x: x[0]) # split the tuple of POS
top_words_df = top_words_df.drop('pos', 1) # drop the previous column
top_words_df.head(10)
# Out:
#    count    Word
# 0    861   apple
# 1    599  google
# 2    595   store
# 3    590    ipad
# 4    516  iphone
# 5    436    ipad
# 6    402     new
# 7    291     app
# 8    206     pop
# 9    199  austin

# %%
fig, ax = plt.subplots(figsize=(15,18))
top_words_df.sort_values(by='count').plot.barh(x='Word',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("100 Top Common Words Found in Tweets")

plt.show()

# %% [markdown]
# ## Ngrams
# **Showing the probability of two, three, or four words showing up.**

# %% [markdown]
# **Bigrams**

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
tweet_finder = BigramCollocationFinder.from_words(tokens)
tweet_scored = tweet_finder.score_ngrams(bigram_measures.raw_freq)
tweet_scored[:20]
# Out:
# [(('apple', 'store'), 0.007257596284110703),
#  (('pop', 'store'), 0.00464486162183085),
#  (('iphone', 'app'), 0.004064253919101994),
#  (('social', 'network'), 0.003257854331978582),
#  (('google', 'map'), 0.003032062447584027),
#  (('new', 'social'), 0.0029998064640990906),
#  (('apple', 'pop'), 0.0026449906457647896),
#  (('google', 'launch'), 0.002386942777885298),
#  (('ipad', 'app'), 0.002386942777885298),
#  (('temporary', 'store'), 0.0023546867944003614),
#  (('store', 'downtown'), 0.0022901748274304886),
#  (('downtown', 'austin'), 0.0022579188439455517),
#  (('apple', 'opening'), 0.002193406876975679),
#  (('network', 'called'), 0.002193406876975679),
#  (('called', 'circle'), 0.0021611508934907425),
#  (('major', 'new'), 0.002128894910005806),
#  (('marissa', 'mayer'), 0.002128894910005806),
#  (('launch', 'major'), 0.0020643829430359332),
#  (('new', 'ipad'), 0.002032126959550997),
#  (('ipad', 'launch'), 0.001903103025611251)]

# %% [markdown]
# **Trigrams**

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
tri_finder = TrigramCollocationFinder.from_words(tokens)
tri_scored = tri_finder.score_ngrams(trigram_measures.raw_freq)
tri_scored[:20]
# Out:
# [(('new', 'social', 'network'), 0.0028062705631894717),
#  (('social', 'network', 'called'), 0.002193406876975679),
#  (('major', 'new', 'social'), 0.002128894910005806),
#  (('network', 'called', 'circle'), 0.002128894910005806),
#  (('launch', 'major', 'new'), 0.0020643829430359332),
#  (('store', 'downtown', 'austin'), 0.0020643829430359332),
#  (('apple', 'pop', 'store'), 0.002032126959550997),
#  (('google', 'launch', 'major'), 0.001903103025611251),
#  (('circle', 'possibly', 'today'), 0.0014837752403070769),
#  (('called', 'circle', 'possibly'), 0.0014515192568221405),
#  (('opening', 'temporary', 'store'), 0.001419263273337204),
#  (('temporary', 'store', 'downtown'), 0.0012257273724275853),
#  (('apple', 'come', 'cool'), 0.001193471388942649),
#  (('apple', 'opening', 'temporary'), 0.001193471388942649),
#  (('come', 'cool', 'technology'), 0.0011289594219727759),
#  (('one', 'ever', 'heard'), 0.0011289594219727759),
#  (('cool', 'technology', 'one'), 0.001064447455002903),
#  (('even', 'begin', 'apple'), 0.001064447455002903),
#  (('technology', 'one', 'ever'), 0.001064447455002903),
#  (('ever', 'heard', 'conference'), 0.0009999354880330302)]

# %% [markdown]
# **Tetragrams**

# %%
tetragram = ngrams(tokens, 4)

# %%
tetragramFreq = collections.Counter(tetragram)
tetragramFreq.most_common(20)
# Out:
# [(('new', 'social', 'network', 'called'), 68),
#  (('social', 'network', 'called', 'circle'), 66),
#  (('launch', 'major', 'new', 'social'), 64),
#  (('major', 'new', 'social', 'network'), 64),
#  (('google', 'launch', 'major', 'new'), 59),
#  (('network', 'called', 'circle', 'possibly'), 45),
#  (('called', 'circle', 'possibly', 'today'), 45),
#  (('temporary', 'store', 'downtown', 'austin'), 37),
#  (('apple', 'opening', 'temporary', 'store'), 35),
#  (('apple', 'come', 'cool', 'technology'), 35),
#  (('opening', 'temporary', 'store', 'downtown'), 33),
#  (('come', 'cool', 'technology', 'one'), 33),
#  (('cool', 'technology', 'one', 'ever'), 33),
#  (('technology', 'one', 'ever', 'heard'), 33),
#  (('one', 'ever', 'heard', 'conference'), 31),
#  (('even', 'begin', 'apple', 'win'), 25),
#  (('store', 'downtown', 'austin', 'ipad'), 24),
#  (('ever', 'heard', 'conference', 'quot'), 24),
#  (('new', 'app', 'store', 'includes'), 23),
#  (('app', 'store', 'includes', 'uberguide'), 23)]

# %% [markdown]
# **Here you can see the most common combos deals with brands and social events. This makes sense when companies like to create events to display their new products, whether it's an app or a phone.**

# %% [markdown]
# # Vectorize Data
#
# **Before building the deep learning model, we are going to split the data into train and test. Then we will vectorize and embed the tweets. To deal with overfitting we will balance the train set and reduce the number of features.**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import plot_confusion_matrix

# %%
y = df1['target']
X = df1['clean_tweet']

# %% [markdown]
# **TF_IDF**

# %%
def tfidf(X, y,  stopwords_list): 
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    vectorizer = TfidfVectorizer(stop_words=stopwords_list)
    tf_idf_train = vectorizer.fit_transform(X_train)
    tf_idf_test = vectorizer.transform(X_test)
    return tf_idf_train, tf_idf_test, y_train, y_test, vectorizer

# %%
tf_idf_train, tf_idf_test, y_train, y_test, vectorizer = tfidf(X, y, stopwords_list)

# %%
tf_idf_train.shape
# Out:
# (2661, 4378)

# %% [markdown]
# # Modeling

# %% [markdown]
# * Logistic Regression - known to be very effective on text data. It's also a great starter algorithm for text classification.
#
# * Random Forest - it's default hyperparameters return great results and the system is great at avoiding overfitting, sometimes.

# %%
lr_classifier = LogisticRegression()
rf_classifier = RandomForestClassifier(n_estimators=100)

# %%
lr_classifier.fit(tf_idf_train, y_train)
lr_train_preds = lr_classifier.predict(tf_idf_train)
lr_test_preds = lr_classifier.predict(tf_idf_test)

# %%
rf_classifier.fit(tf_idf_train, y_train)
rf_train_preds = rf_classifier.predict(tf_idf_train)
rf_test_preds = rf_classifier.predict(tf_idf_test)

# %%
lr_train_score = accuracy_score(y_train, lr_train_preds)
lr_test_score = accuracy_score(y_test, lr_test_preds)

rf_train_score = accuracy_score(y_train, rf_train_preds)
rf_test_score = accuracy_score(y_test, rf_test_preds)


print('Logistic Regression')
print("Training Accuracy: {:.4} \t\t Testing Accuracy: {:.4}".format(lr_train_score, lr_test_score))
print("")
print('-'*70)
print("")
print('Random Forest')
print("Training Accuracy: {:.4} \t\t Testing Accuracy: {:.4}".format(rf_train_score, rf_test_score))
# Out:
# Logistic Regression
# Training Accuracy: 0.8591 		 Testing Accuracy: 0.8512
#
# ----------------------------------------------------------------------
#
# Random Forest
# Training Accuracy: 0.9996 		 Testing Accuracy: 0.8794

# %% [markdown]
# **The models did okay. Since there are three classes, the naive accuracy rate would be ~33%. With scores of 68, 66, and 68 percent did much better than random guessing. With RF there seems to be some evidence of overfitting. This model can be improved with some tuning.**

# %%
def confusion_plot(classifier):
    class_names = ['positive', 'negative']
    titles_options = [(f"{classifier}Confusion matrix, without normalization", None),
                      ("Normalized confusion matrix", 'true')]
    for title, normalize in titles_options:
        disp = plot_confusion_matrix(classifier, tf_idf_test, y_test,
                                     display_labels=class_names,
                                     cmap=plt.cm.Blues,
                                     normalize=normalize)
                                 
        disp.ax_.set_title(title)
        
#         print(title)
#         print(disp.confusion_matrix)
    print(classification_report(y_test, classifier.predict(tf_idf_test)))
    return plt.show()

# %%
confusion_plot(rf_classifier)
confusion_plot(lr_classifier)
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.27      0.41       137
#     positive       0.88      0.99      0.93       750
#
#     accuracy                           0.88       887
#    macro avg       0.86      0.63      0.67       887
# weighted avg       0.88      0.88      0.85       887
#               precision    recall  f1-score   support
#
#     negative       0.73      0.06      0.11       137
#     positive       0.85      1.00      0.92       750
#
#     accuracy                           0.85       887
#    macro avg       0.79      0.53      0.51       887
# weighted avg       0.83      0.85      0.79       887

# %%
rf_classifier_2 = RandomForestClassifier(n_estimators=200, min_samples_leaf= 5,
                                         min_samples_split = 20)

rf_classifier_2.fit(tf_idf_train, y_train)
rf_train_preds = rf_classifier_2.predict(tf_idf_train)
rf_test_preds = rf_classifier_2.predict(tf_idf_test)

rf_train_score = accuracy_score(y_train, rf_train_preds)
rf_test_score = accuracy_score(y_test, rf_test_preds)

print(rf_train_score, rf_test_score)
# Out:
# 0.8511837655016911 0.8579481397970687

# %%
confusion_plot(rf_classifier_2)
# Out:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.08      0.15       137
#     positive       0.86      1.00      0.92       750
#
#     accuracy                           0.86       887
#    macro avg       0.93      0.54      0.54       887
# weighted avg       0.88      0.86      0.80       887

# %% [markdown]
# **Since for all the models the recall is lower than the precision. In this case, the model has problems detecting the class well but when it does the results are somewhat trustworthy. Class imbalance might have some cause for this. For now Random Forest has the best model so far. Next going to try to tune some of the parameters to get a better accuracy and recall.**

# %%
from sklearn.model_selection import GridSearchCV

# %%
forest_clf = RandomForestClassifier(n_estimators=100)
forest_model = forest_clf.fit(tf_idf_train, y_train)

# %%
min_split = range(5, 20)
min_leaf = range(5,20)

# %%
weights = [None, 'balanced', {1:2, 0:1}, {1:10, 0:1}, {1:100, 0:1}, {1:1000, 0:1}]
names = ['None', 'Balanced', '2 to 1', '10 to 1', '100 to 1', '1000 to 1']

# %%
forest_params = {'criterion' : ['gini', 'entropy'],
                 'min_samples_split' : [5, 10, 15, 20],
                 'min_samples_leaf' : [5, 10, 15, 20],
                'class_weight': [None, 'balanced']}
grid_search = GridSearchCV(forest_model, param_grid=forest_params, scoring='accuracy')
grid_search.fit(tf_idf_train, y_train)

# %%
grid_search.best_params_

# %% [markdown]
# ## Word2Vec

# %%
from gensim.models import Word2Vec

# %%
data = df1['clean_tweet'].map(word_tokenize)
data[:5]

# %%
model = Word2Vec(data, size=100, window=5, min_count=2, workers=4)

# %%
model.train(data, total_examples=model.corpus_count, epochs=10)

# %%
wv = model.wv

# %%
wv.vocab

# %%
wv.most_similar('apple')

# %% [markdown]
# # Future Recommendations
#
# * **1. Look into the Neutral comments and get rid of comments not related to the subject.**
# * **2. Scrape for more data to possibly balance the three classes, especially negative and positive comments.**
# * **3.
